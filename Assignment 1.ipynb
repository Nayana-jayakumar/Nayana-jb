# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Read the dataset to python environment.

# %%
data = pd.read_excel(r"C:\Users\jbnay\Downloads\iris.xls")

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2.Display the columns in the dataset

# %%
data.columns                                     #display the columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3. Calculate the mean of each columns of the dataset.

# %%
data.mean()
# Out:
# C:\Users\jbnay\AppData\Local\Temp\ipykernel_21844\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4. Check for the null values present in the dataset.

# %%
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# There is no null values in the dataset.

# %% [markdown]
# 5.Visualizations using the dataset.

# %% [markdown]
# #Boxplot

# %%
plt.figure(figsize = (10, 7))
data.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# sepal width shows outlier data.

# %% [markdown]
# #Histogram

# %%
plt.figure(figsize = (10, 7))
x = data["SL"]
plt.hist(x, bins = 20, color = "green")
plt.title("Sepal Length in cm")
plt.xlabel("Sepal_Length_cm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (10, 7))
x = data.SW
plt.hist(x, bins = 20, color = "green")
plt.title("Sepal Width in cm")
plt.xlabel("Sepal_Width_cm")
plt.ylabel("Count")
  
plt.show()

# %%
plt.figure(figsize = (10, 7))
x = data.PL
plt.hist(x, bins = 20, color = "green")
plt.title("Petal Length in cm")
plt.xlabel("Petal_Length_cm")
plt.ylabel("Count")
  
plt.show()

# %%
plt.figure(figsize = (10, 7))
x = data.PW
plt.hist(x, bins = 20, color = "green")
plt.title("Petal Width in cm")
plt.xlabel("Petal_Width_cm")
plt.ylabel("Count")
  
plt.show()

# %%
plt.scatter(data['SW'],data['Classification'])
plt.xlabel('sepal width')
plt.ylabel('Classification')
# Out:
# Text(0, 0.5, 'Classification')

# %%
plt.scatter(data['PL'],data['Classification'])
plt.xlabel('petal length')
plt.ylabel('Classification')
# Out:
# Text(0, 0.5, 'Classification')

# %%
plt.scatter(data['PW'],data['Classification'])
plt.xlabel('petal width')
plt.ylabel('Classification')
# Out:
# Text(0, 0.5, 'Classification')

# %% [markdown]
# For Iris-virginica have greater sepal and petal size and Iris-setosa having least sepal and petal size.
