# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\jbnay\Downloads\StudentsPerformance (2).csv")

# %% [markdown]
# 1. Find out how many males and females participated in the test.

# %%
gender_count=data.gender.value_counts() 
gender_count
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# 2. What do you think about the students' parental level of education?

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(y="parental level of education", x="math score", data=data)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(y="parental level of education", x="reading score", data=data)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(y="parental level of education", x="writing score", data=data)
plt.show()

# %% [markdown]
# Those who scores good at math,reading,writing have maximimum entry to higher parental education.

# %% [markdown]
# 3. Who scores the most on average for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(x="gender", y="math score", data=data)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(x="gender", y="reading score", data=data)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(x="gender", y="writing score", data=data)
plt.show()

# %% [markdown]
# Female score most on math,reading,writing

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(x="test preparation course", y="math score", data=data)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(x="test preparation course", y="reading score", data=data)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(x="test preparation course", y="writing score", data=data)
plt.show()

# %% [markdown]
# Those who completed test preparation course scores most in all cases.
